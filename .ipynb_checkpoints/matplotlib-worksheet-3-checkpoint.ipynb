# %% [markdown]
# This worksheet consist of Questions from the topics covered in matplotlib-4.ipynb notebook.
# Approach to solve the questions is similar to the previous two worksheets.
#
# All the best

# %% [markdown]
# ## 1. Write code for the plot given below:
# ![Q1-S3.png](attachment:Q1-S3.png)
#
# #### Note-> figure size = (12,12), value of 'x' for each plot is of length 10 having range mentioned in the x-label for each plot. Change the title according to yourself.  Also function for each plot is mentioned on the y axis for each plot.

# %% [markdown]
# ## 2. Write code for the plot with following specifications:
# * figure size = (8,8)
# * x = 100 equally spaced values in range (-3,3), x will be same for all 4 subplots
# * y1 = x^2, linecolor = blue, facecolor = white
# * y2 = 3*x ,linecolor = yellow, facecolor = cyan
# * y3 = e^(-x), linecolor = red, facecolor = yellow
# * y4 = sin(x), linecolor = black, facecolor = green
# * Also use appropriate y_label for each subplot

# %% [markdown]
# ## 3. Write the code for the plot given below:
# ![Q3-S3.png](attachment:Q3-S3.png)

# %% [markdown]
# ## 4. Write code to draw a contour plot with following specifications:
# * X = 100 equally spaced values in range(-3,3)
# * Y = 100 equally spaced values in range(-3,3)
# * Z = squareroot of (X^2+Y^2)
# * levels = a list of values 0.0, 0.2, 0.5, 0.9, 1.5, 2.5, 3.5
# * contours = first use contour function and color of contour should be black and levels should be the ones defined above
# * countour filled = fill the contour with levels defined above
# * Add colorbar for contour filled
# * Use appropriate title, xlabel and ylabel
