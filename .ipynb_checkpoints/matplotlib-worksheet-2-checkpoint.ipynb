# %% [markdown]
# This worksheet consist of Questions from the topics we've covered in matplotlib-3.ipynb notebook.
# Approach to solve each Question is similar to that of the previous one.
#
# All the best

# %% [markdown]
# ## 1. Write code for the bar plot given below:
#
# ![Q1_S2.png](attachment:Q1_S2.png)
#
# Note-> This is horizontal bar graph in which we use the function barh() instead of bar() and revert the values of X and Y whe compared to bar() function. All the other things are exactly similar to that of simple bar() function

# %% [markdown]
# ## 2. Write code for the comparison bar graph given below with data:
# * figure size = (8,9)
# * X_index = Subjects as -> Maths,English,Physics,Chemistry
# * Student_1 marks = 95,69,84,76 (marks here are in the order of the subjects mentioned above)
# * Student_2 marks = 85,53,65,74
#
# ![Q2_S2.png](attachment:Q2_S2.png)

# %% [markdown]
# ## 3. Draw a pie-chart for the Favourtie beverage data given below:
# * figure-size = (8,8)
# * beverages -> Tea,Coffee,Coke,Water,Other
# * Values -> 75,46,76,87,40 (Values for consumption of beverages are in the same order of beverages as mentioned above)
# * explode values = 0.0,0.1,0.0,0.0,0.1
#
# Note-> Also display the percentage values(upto 2 decimal places) of each and every beverage within the pie-chart, and also enable shadow for the pir chart in the given solution

# %% [markdown]
# ## 4. Plot a histogram for any 7 random integers between 100 and 200

# %% [markdown]
# ## 5. Draw a scatter plot with following specifications :
# * figure size = (10,8)
# * X = 50 random standard normal values
# * y1 = 50 random standard normal values, marker = triangle up, color = blue along with appropriate label.
# * y2 = 50 random standard normal values, marker = pentagon, color = green along with appropriate label.
# * y3 = 50 random standard normal values, marker = circle, color = red along with appropriate label.
# * title -> scatter plot for three different values of Y
# * Also, give appropriate x label and y label.
