# %% [markdown]
# This worksheet consist of some Questions from what we've studied in matplotlib-1.ipynb and matplotlib-2.ipynb
# I hope you all are able to attempt all the questions. Every question is from what've studied so far.
#
# How to attempt ?
# Each question has a block given below, use it to write code and plot the graphs.
#
# All the best.

# %% [markdown]
# ## 1. Draw a simple line plot in the block given below,  for the function 'y=x^2+4x+1', where x must range from (-5,5) and length of x must be 20.

# %% [markdown]
# ## 2. Write code for the plot given below:
#
# ![Q2_S1.png](attachment:Q2_S1.png)
#
# NOTE-> The function for the plot above is mentioned in the title of the plot.

# %% [markdown]
# ## 3. Draw a multi-line plot having a figure size of (8,10), and must have grid enabled as well, for three different functions mentioned below:
# ## -> y = x^2
# ## -> y = exp(x)
# ## -> y = 3*x

# %% [markdown]
# ## 4. Write code for the plot given below:
#
# ![Q4_S1.png](attachment:Q4_S1.png)
#
# ## x-axis, x must have 20 equally spaced values in range (0,6)
# NOTE-> The functions for the multi-line plot are mentioned in the plot itself and all the other details are mentioned in the title of the plot.(including figure size and degree of rotation of xticks and yticks).
